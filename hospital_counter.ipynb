# %%
#This is a data cleaning file included for completeness. Not neccesary to run.

# %%
tdf = pd.read_csv('FacilityList.csv')
counties = []
counts = []
for index, row in tdf.iterrows():
    if row[12] in counties:
        counts[counties.index(row[12])]+=1
    else:
        counties.append(row[12])
        counts.append(1)

df3 = pd.DataFrame({"County":counties,"Counts":counts})
df3
# Out:
# C:\Users\amsba\AppData\Local\Temp\ipykernel_24996\2362693475.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[12] in counties:
# C:\Users\amsba\AppData\Local\Temp\ipykernel_24996\2362693475.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   counties.append(row[12])
# C:\Users\amsba\AppData\Local\Temp\ipykernel_24996\2362693475.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   counts[counties.index(row[12])]+=1
#              County  Counts
# 0             Butte      15
# 1         Riverside      79
# 2    San Bernardino      79
# 3        Sacramento      58
# 4         San Diego     112
# 5         Calaveras       2
# 6            Madera       8
# 7            Colusa       2
# 8       Santa Clara      67
# 9            Orange     109
# 10          Alameda      90
# 11     Contra Costa      40
# 12        El Dorado       5
# 13           Fresno      47
# 14            Glenn       2
# 15         Humboldt      10
# 16         Imperial       6
# 17             Inyo       3
# 18             Kern      31
# 19             Lake       5
# 20            Marin      16
# 21         Mariposa       1
# 22      Los Angeles     510
# 23        San Mateo      22
# 24       Stanislaus      30
# 25           Solano      15
# 26          Ventura      30
# 27         Siskiyou       3
# 28       Santa Cruz      10
# 29  San Luis Obispo      12
# 30           Placer      13
# 31             Mono       1
# 32        Mendocino       7
# 33           Sonoma      27
# 34    San Francisco      28
# 35    Santa Barbara      21
# 36           Shasta      12
# 37           Tehama       3
# 38          Trinity       1
# 39           Tulare      20
# 40         Tuolumne       4
# 41             Yolo       8
# 42             Yuba       2
# 43            Kings       4
# 44            Modoc       2
# 45      San Joaquin      36
# 46           Amador       2
# 47        Del Norte       2
# 48           Merced      12
# 49         Monterey      18
# 50             Napa       6
# 51           Nevada       6
# 52           Plumas       3
# 53           Sutter       5
# 54           Lassen       2
# 55       San Benito       2
# 56           Sierra       1

# %%
popdens = pd.read_csv("CACountiesPopDensity.csv")
l = []
for row in popdens['County']:
    l.append(row.split(',')[0])

popdens['County'] = pd.Series(l)
popdens
# Out:
#     Density           County
# 0    3575.3    San Francisco
# 1    3255.4           Orange
# 2    2099.4      Los Angeles
# 3    1898.5          Alameda
# 4    1459.0       Sacramento
# 5    1412.2      Santa Clara
# 6    1345.2     Contra Costa
# 7     998.5        San Mateo
# 8     703.4        San Diego
# 9     491.4      San Joaquin
# 10    465.3           Solano
# 11    440.1       Santa Cruz
# 12    378.5          Ventura
# 13    345.2       Stanislaus
# 14    310.4        Riverside
# 15    310.1            Marin
# 16    278.2           Sonoma
# 17    240.6           Placer
# 18    199.5             Yolo
# 19    176.6             Napa
# 20    157.8           Fresno
# 21    156.2           Sutter
# 22    132.2           Merced
# 23    132.1            Butte
# 24    113.9    Santa Barbara
# 25    113.5             Yuba
# 26    112.7         Monterey
# 27    108.8            Kings
# 28    105.1             Kern
# 29    103.4   San Bernardino
# 30    101.6        El Dorado
# 31    101.3           Nevada
# 32     93.2           Tulare
# 33     75.8  San Luis Obispo
# 34     70.8           Madera
# 35     61.3           Amador
# 36     48.3             Lake
# 37     46.4           Shasta
# 38     43.3        Calaveras
# 39     40.9       San Benito
# 40     39.5         Imperial
# 41     33.3         Humboldt
# 42     23.9         Tuolumne
# 43     22.8        Del Norte
# 44     22.6        Mendocino
# 45     21.4           Tehama
# 46     21.1            Glenn
# 47     18.5           Colusa
# 48     12.3         Mariposa
# 49      7.4           Plumas
# 50      7.1           Lassen
# 51      7.0         Siskiyou
# 52      4.5             Mono
# 53      4.2          Trinity
# 54      3.1           Sierra
# 55      2.2            Modoc
# 56      1.8             Inyo
# 57      1.6           Alpine

# %%
beds_df = pd.read_csv('healthcare_facility_beds.csv')
countyarr = []
for row in beds_df['COUNTY_NAME']:
    arr = row.lower().split(" ")
    newstr = ""
    for x in arr:
        x = x[0].upper()+x[1:]
        newstr+=(x)+" "
    countyarr.append(newstr[:-1])

beds_df['County'] = pd.Series(countyarr)


counties = []
beds = []
for index, row in beds_df.iterrows():
    if row[7] in counties:
        beds[counties.index(row[7])]+=int(row[4])
    else:
        counties.append(row[7])
        beds.append(int(row[4]))

new_bed_df = pd.DataFrame({"County":counties,"Beds":beds})
# Out:
# C:\Users\amsba\AppData\Local\Temp\ipykernel_24996\2668370092.py:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if row[7] in counties:
# C:\Users\amsba\AppData\Local\Temp\ipykernel_24996\2668370092.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   counties.append(row[7])
# C:\Users\amsba\AppData\Local\Temp\ipykernel_24996\2668370092.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   beds.append(int(row[4]))
# C:\Users\amsba\AppData\Local\Temp\ipykernel_24996\2668370092.py:18: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   beds[counties.index(row[7])]+=int(row[4])
#              County   Beds
# 0            Sonoma   2653
# 1         Del Norte    176
# 2          Humboldt    708
# 3         Mendocino    423
# 4              Napa   2477
# 5            Solano   2440
# 6             Marin   1662
# 7           Alameda   9197
# 8      Contra Costa   5228
# 9            Placer   2058
# 10       Sacramento   8273
# 11        Calaveras    124
# 12       Stanislaus   3531
# 13         Tuolumne    375
# 14        El Dorado    512
# 15           Amador    273
# 16      San Joaquin   5508
# 17             Yolo    845
# 18           Fresno   6999
# 19           Madera   1030
# 20           Merced   1233
# 21            Kings    653
# 22         Mariposa     34
# 23          Ventura   3817
# 24  San Luis Obispo   2697
# 25    Santa Barbara   2356
# 26           Orange  15793
# 27      Los Angeles  70722
# 28      Santa Clara   9712
# 29         Monterey   2102
# 30       Santa Cruz   1135
# 31       San Benito    157
# 32        San Diego  17607
# 33         Imperial    612
# 34             Lake    367
# 35           Shasta   1745
# 36           Sutter    501
# 37           Nevada    596
# 38             Kern   4153
# 39           Tulare   3238
# 40        San Mateo   3102
# 41           Lassen    151
# 42        Riverside  10471
# 43   San Bernardino  12047
# 44    San Francisco   5280
# 45            Butte   1471
# 46           Plumas     78
# 47            Glenn    132
# 48            Modoc     84
# 49         Siskiyou    126
# 50           Tehama    189
# 51          Trinity     38
# 52           Colusa    147
# 53             Yuba    313
# 54           Sierra     39
# 55             Mono     17
# 56             Inyo    161
